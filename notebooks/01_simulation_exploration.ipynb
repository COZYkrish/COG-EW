# %% [markdown]
# # Cognitive Multi-Domain EW–Guidance Co-Designer: Simulation Exploration
# This notebook demonstrates initializing the Hypersonic EW POMDP environment, running baseline flight trajectories, and visualizing threat dynamics.

# %%
import sys
sys.path.append('..')
from sim.environment import HypersonicEWEnv
from guidance.baseline_guidance import ProportionalNavigation

env = HypersonicEWEnv()
obs, _ = env.reset()
print('Initial observation vector shape:', obs.shape)
print('Initial observation values:', obs)
